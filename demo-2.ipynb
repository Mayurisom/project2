# %%
a=5
b=9
print(a+b)
# Out:
# 14

# %%
import pandas as pd
df = pd.DataFrame ({"Roll number": [1,2,3,4,5], "Name" :["Mayu","Mayur","Mayuri","mai","maya"]}) 
df.to_excel("student.xlsx", index="false")

# %%
df.to_csv("student_csv_file.csv", index="false")

# %% [markdown]
# ### image
#
# ![image-2.png](attachment:image-2.png)
